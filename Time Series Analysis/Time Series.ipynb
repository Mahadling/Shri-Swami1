# %% [markdown]
# # Time Series Decomposition

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv('AirPassengers.csv')

# %%
df
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df.columns = ['Month', 'nPass']

# %%
df.head()
# Out:
#      Month  nPass
# 0  1949-01    112
# 1  1949-02    118
# 2  1949-03    132
# 3  1949-04    129
# 4  1949-05    121

# %%
df['Month'] = pd.to_datetime(df['Month'])

# %%
df.dtypes
# Out:
# Month    datetime64[ns]
# nPass             int64
# dtype: object

# %%
df.head()
# Out:
#        Month  nPass
# 0 1949-01-01    112
# 1 1949-02-01    118
# 2 1949-03-01    132
# 3 1949-04-01    129
# 4 1949-05-01    121

# %%
df.index = df['Month']

# %%
df
# Out:
#                 Month  nPass
# Month
# 1949-01-01 1949-01-01    112
# 1949-02-01 1949-02-01    118
# 1949-03-01 1949-03-01    132
# 1949-04-01 1949-04-01    129
# 1949-05-01 1949-05-01    121
# ...               ...    ...
# 1960-08-01 1960-08-01    606
# 1960-09-01 1960-09-01    508
# 1960-10-01 1960-10-01    461
# 1960-11-01 1960-11-01    390
# 1960-12-01 1960-12-01    432
#
# [144 rows x 2 columns]

# %%
C = df.iloc[0:37, :]

# %%
C
# Out:
#                 Month  nPass
# Month
# 1949-01-01 1949-01-01    112
# 1949-02-01 1949-02-01    118
# 1949-03-01 1949-03-01    132
# 1949-04-01 1949-04-01    129
# 1949-05-01 1949-05-01    121
# 1949-06-01 1949-06-01    135
# 1949-07-01 1949-07-01    148
# 1949-08-01 1949-08-01    148
# 1949-09-01 1949-09-01    136
# 1949-10-01 1949-10-01    119
# 1949-11-01 1949-11-01    104
# 1949-12-01 1949-12-01    118
# 1950-01-01 1950-01-01    115
# 1950-02-01 1950-02-01    126
# 1950-03-01 1950-03-01    141
# 1950-04-01 1950-04-01    135
# 1950-05-01 1950-05-01    125
# 1950-06-01 1950-06-01    149
# 1950-07-01 1950-07-01    170
# 1950-08-01 1950-08-01    170
# 1950-09-01 1950-09-01    158
# 1950-10-01 1950-10-01    133
# 1950-11-01 1950-11-01    114
# 1950-12-01 1950-12-01    140
# 1951-01-01 1951-01-01    145
# 1951-02-01 1951-02-01    150
# 1951-03-01 1951-03-01    178
# 1951-04-01 1951-04-01    163
# 1951-05-01 1951-05-01    172
# 1951-06-01 1951-06-01    178
# 1951-07-01 1951-07-01    199
# 1951-08-01 1951-08-01    199
# 1951-09-01 1951-09-01    184
# 1951-10-01 1951-10-01    162
# 1951-11-01 1951-11-01    146
# 1951-12-01 1951-12-01    166
# 1952-01-01 1952-01-01    171

# %%
D = df.iloc[108:, :]
D
# Out:
#                 Month  nPass
# Month
# 1958-01-01 1958-01-01    340
# 1958-02-01 1958-02-01    318
# 1958-03-01 1958-03-01    362
# 1958-04-01 1958-04-01    348
# 1958-05-01 1958-05-01    363
# 1958-06-01 1958-06-01    435
# 1958-07-01 1958-07-01    491
# 1958-08-01 1958-08-01    505
# 1958-09-01 1958-09-01    404
# 1958-10-01 1958-10-01    359
# 1958-11-01 1958-11-01    310
# 1958-12-01 1958-12-01    337
# 1959-01-01 1959-01-01    360
# 1959-02-01 1959-02-01    342
# 1959-03-01 1959-03-01    406
# 1959-04-01 1959-04-01    396
# 1959-05-01 1959-05-01    420
# 1959-06-01 1959-06-01    472
# 1959-07-01 1959-07-01    548
# 1959-08-01 1959-08-01    559
# 1959-09-01 1959-09-01    463
# 1959-10-01 1959-10-01    407
# 1959-11-01 1959-11-01    362
# 1959-12-01 1959-12-01    405
# 1960-01-01 1960-01-01    417
# 1960-02-01 1960-02-01    391
# 1960-03-01 1960-03-01    419
# 1960-04-01 1960-04-01    461
# 1960-05-01 1960-05-01    472
# 1960-06-01 1960-06-01    535
# 1960-07-01 1960-07-01    622
# 1960-08-01 1960-08-01    606
# 1960-09-01 1960-09-01    508
# 1960-10-01 1960-10-01    461
# 1960-11-01 1960-11-01    390
# 1960-12-01 1960-12-01    432

# %% [markdown]
# ### Drop Month Column

# %%
df = df.drop(columns=['Month'])
df.head()
# Out:
#             nPass
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %% [markdown]
# ### Visualize data with Matplotlib

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(df['nPass'])
plt.xlabel('Months')
plt.ylabel('Number of Passenger')
plt.title('Air Passenger over time')
plt.show()

# %% [markdown]
# ### Decompose time series to Seasson, Trend and Residual

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
Q = seasonal_decompose(df['nPass'], model='mutiplicative')
Q.plot()

# %%
plt.figure(figsize=(16,8))
Q.observed.plot()
Q.trend.plot()
plt.xlabel('Month')
plt.ylabel('Number Of Air Passengers')
plt.title('Air Passengers Trend Analysis')
plt.show()

# %%
plt.figure(figsize=(16,8))
Q.seasonal.plot()
plt.xlabel('Month')
plt.ylabel('nPass')
plt.title('Seasonality of Passengers')
plt.show()

# %%
plt.figure(figsize=(16,8))
Q.resid.plot()
plt.xlabel('Month')
plt.ylabel('nPass')
plt.title('Residuals of Passengers')
plt.show()

# %% [markdown]
# ### Time series forcasting

# %%
# %pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in e:\github repository\repository\venv\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in e:\github repository\repository\venv\lib\site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in e:\github repository\repository\venv\lib\site-packages (from pmdarima) (3.0.5)
# Requirement already satisfied: numpy>=1.21.2 in e:\github repository\repository\venv\lib\site-packages (from pmdarima) (1.25.2)
# Requirement already satisfied: pandas>=0.19 in e:\github repository\repository\venv\lib\site-packages (from pmdarima) (2.1.0)
# Requirement already satisfied: scikit-learn>=0.22 in e:\github repository\repository\venv\lib\site-packages (from pmdarima) (1.3.0)
# Requirement already satisfied: scipy>=1.3.2 in e:\github repository\repository\venv\lib\site-packages (from pmdarima) (1.11.2)
# Requirement already satisfied: statsmodels>=0.13.2 in e:\github repository\repository\venv\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in e:\github repository\repository\venv\lib\site-packages (from pmdarima) (2.1.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in e:\github repository\repository\venv\lib\site-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: packaging>=17.1 in e:\github repository\repository\venv\lib\site-packages (from pmdarima) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\github repository\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\github repository\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\github repository\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\github repository\repository\venv\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in e:\github repository\repository\venv\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in e:\github repository\repository\venv\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pmdarima.arima import auto_arima

# %%
model = auto_arima(df['nPass'], m=12)

# %%
model.order
# Out:
# (2, 1, 1)

# %%
p = model.order[0]
d = model.order[1]
q = model.order[2]
print(f'Model Order, p:{p} ; d:{d} ; q:{q}')
# Out:
# Model Order, p:2 ; d:1 ; q:1

# %% [markdown]
# ### Getting the forecast along with confidence interval

# %%
forecast, conf_int = model.predict(n_periods = 36, return_conf_int=True)

# %%
forecast
# Out:
# 1961-01-01    445.634934
# 1961-02-01    420.395042
# 1961-03-01    449.198378
# 1961-04-01    491.840023
# 1961-05-01    503.394565
# 1961-06-01    566.862550
# 1961-07-01    654.260284
# 1961-08-01    638.597604
# 1961-09-01    540.883864
# 1961-10-01    494.126748
# 1961-11-01    423.332841
# 1961-12-01    465.507712
# 1962-01-01    479.291026
# 1962-02-01    454.177037
# 1962-03-01    483.087203
# 1962-04-01    525.819493
# 1962-05-01    537.450950
# 1962-06-01    600.984197
# 1962-07-01    688.437307
# 1962-08-01    672.821614
# 1962-09-01    575.147743
# 1962-10-01    528.424456
# 1962-11-01    457.659254
# 1962-12-01    499.858481
# 1963-01-01    513.662462
# 1963-02-01    488.566008
# 1963-03-01    517.491053
# 1963-04-01    560.235969
# 1963-05-01    571.878138
# 1963-06-01    635.420475
# 1963-07-01    722.881298
# 1963-08-01    707.272149
# 1963-09-01    609.603831
# 1963-10-01    562.885256
# 1963-11-01    492.124052
# 1963-12-01    534.326671
# Freq: MS, dtype: float64

# %%
forecast = forecast.apply(round)
forecast
# Out:
# 1961-01-01    446
# 1961-02-01    420
# 1961-03-01    449
# 1961-04-01    492
# 1961-05-01    503
# 1961-06-01    567
# 1961-07-01    654
# 1961-08-01    639
# 1961-09-01    541
# 1961-10-01    494
# 1961-11-01    423
# 1961-12-01    466
# 1962-01-01    479
# 1962-02-01    454
# 1962-03-01    483
# 1962-04-01    526
# 1962-05-01    537
# 1962-06-01    601
# 1962-07-01    688
# 1962-08-01    673
# 1962-09-01    575
# 1962-10-01    528
# 1962-11-01    458
# 1962-12-01    500
# 1963-01-01    514
# 1963-02-01    489
# 1963-03-01    517
# 1963-04-01    560
# 1963-05-01    572
# 1963-06-01    635
# 1963-07-01    723
# 1963-08-01    707
# 1963-09-01    610
# 1963-10-01    563
# 1963-11-01    492
# 1963-12-01    534
# Freq: MS, dtype: int64

# %%
conf_int
# Out:
# array([[423.34475094, 467.92511658],
#        [394.23518302, 446.55490116],
#        [419.83140846, 478.56534829],
#        [460.37587373, 523.30417201],
#        [470.37999658, 536.40913406],
#        [532.69880168, 601.02629843],
#        [619.22055901, 689.30000963],
#        [602.87921604, 674.31599104],
#        [504.63055231, 577.13717502],
#        [457.44514984, 530.80834643],
#        [386.3030106 , 460.36267117],
#        [428.19044593, 502.82497842],
#        [433.49653884, 525.08551376],
#        [405.10774907, 503.24632483],
#        [431.15437638, 535.02002912],
#        [471.83916844, 579.79981805],
#        [481.87209035, 593.02980929],
#        [544.15500525, 657.81338881],
#        [630.60709073, 746.26752372],
#        [614.17741433, 731.46581272],
#        [515.83056926, 634.46491613],
#        [468.54219966, 588.30671331],
#        [397.2952923 , 518.02321528],
#        [439.07790127, 560.63906114],
#        [446.32509131, 580.99983223],
#        [418.31603539, 558.81598086],
#        [444.62194643, 590.36015987],
#        [485.39943994, 635.07249774],
#        [495.4479624 , 648.30831366],
#        [557.69634351, 713.1446065 ],
#        [644.08397085, 801.67862509],
#        [627.57137805, 786.97291922],
#        [529.13050031, 690.07716124],
#        [481.74160891, 644.02890374],
#        [410.39065083, 573.85745237],
#        [452.0675645 , 616.58577818]])

# %%
lower_conf = conf_int[:, 0 ]
lower_conf
# Out:
# array([423.34475094, 394.23518302, 419.83140846, 460.37587373,
#        470.37999658, 532.69880168, 619.22055901, 602.87921604,
#        504.63055231, 457.44514984, 386.3030106 , 428.19044593,
#        433.49653884, 405.10774907, 431.15437638, 471.83916844,
#        481.87209035, 544.15500525, 630.60709073, 614.17741433,
#        515.83056926, 468.54219966, 397.2952923 , 439.07790127,
#        446.32509131, 418.31603539, 444.62194643, 485.39943994,
#        495.4479624 , 557.69634351, 644.08397085, 627.57137805,
#        529.13050031, 481.74160891, 410.39065083, 452.0675645 ])

# %%
 lower_conf = list(map(round, lower_conf))
lower_conf[0:5]
# Out:
# [423, 394, 420, 460, 470]

# %%
upper_conf = conf_int[:, 1]
upper_conf
# Out:
# array([467.92511658, 446.55490116, 478.56534829, 523.30417201,
#        536.40913406, 601.02629843, 689.30000963, 674.31599104,
#        577.13717502, 530.80834643, 460.36267117, 502.82497842,
#        525.08551376, 503.24632483, 535.02002912, 579.79981805,
#        593.02980929, 657.81338881, 746.26752372, 731.46581272,
#        634.46491613, 588.30671331, 518.02321528, 560.63906114,
#        580.99983223, 558.81598086, 590.36015987, 635.07249774,
#        648.30831366, 713.1446065 , 801.67862509, 786.97291922,
#        690.07716124, 644.02890374, 573.85745237, 616.58577818])

# %%
upper_conf = list(map(round, upper_conf))
upper_conf[0:5]
# Out:
# [468, 447, 479, 523, 536]

# %% [markdown]
# ### Plot the forecast graph along with original data

# %%
plt.figure(figsize=(16,8))
plt.plot(df['nPass'], label='Original')
plt.plot(forecast, label='forecast')
plt.fill_between(x=forecast.index, y1 = lower_conf, y2= upper_conf, label='confidence interval', color ='gray',alpha= 0.5 )
plt.xlabel('Months')
plt.ylabel('Number of Passengers')
plt.title('Air Passengers Forecast Sheet')
plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# ### Saving forecast data into dataframe
